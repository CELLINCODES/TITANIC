# %%
from google.colab import files
import pandas as pd

# Carregar o arquivo CSV
uploaded = files.upload()

# Ler o arquivo CSV com o Pandas (substitua 'nome_do_arquivo.csv' pelo nome real do arquivo)
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#      <input type="file" id="files-9f839a9b-920f-4b1a-80ab-8b5ddd47be59" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f839a9b-920f-4b1a-80ab-8b5ddd47be59">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#from google.colab import drive
#drive.mount('/content/drive/titanic.csv')

# %%
f = open("titanic.csv", "r") #confirmar se foi
print(f.read())
# Out:
# PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
# 892,0,3,"Kelly, Mr. James",male,34.5,0,0,330911,7.8292,,Q
# 893,1,3,"Wilkes, Mrs. James (Ellen Needs)",female,47,1,0,363272,7,,S
# 894,0,2,"Myles, Mr. Thomas Francis",male,62,0,0,240276,9.6875,,Q
# 895,0,3,"Wirz, Mr. Albert",male,27,0,0,315154,8.6625,,S
# 896,1,3,"Hirvonen, Mrs. Alexander (Helga E Lindqvist)",female,22,1,1,3101298,12.2875,,S
# 897,0,3,"Svensson, Mr. Johan Cervin",male,14,0,0,7538,9.225,,S
# 898,1,3,"Connolly, Miss. Kate",female,30,0,0,330972,7.6292,,Q
# 899,0,2,"Caldwell, Mr. Albert Francis",male,26,1,1,248738,29,,S
# 900,1,3,"Abrahim, Mrs. Joseph (Sophie Halaut Easu)",female,18,0,0,2657,7.2292,,C
# 901,0,3,"Davies, Mr. John Samuel",male,21,2,0,A/4 48871,24.15,,S
# 902,0,3,"Ilieff, Mr. Ylio",male,,0,0,349220,7.8958,,S
# 903,0,1,"Jones, Mr. Charles Cresson",male,46,0,0,694,26,,S
# 904,1,1,"Snyder, Mrs. John Pillsbury (Nelle Stevenson)",female,23,1,0,21228,82.2667,B45,S
# ...

# %%
# Carregar o conjunto de dados Titanic
titanic_df = pd.read_csv('titanic.csv')
# Exibir algumas linhas com valores NaN
print(titanic_df.head())
print(titanic_df.isna().sum())
# Exibir o DataFrame original
print("DataFrame original:")
print(titanic_df)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# ...

# %%
print(df.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
titanic_df = df.dropna(subset=['Age','Cabin'])
print(titanic_df.isna().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
print(titanic_df.head())
print(titanic_df.isna().sum())
print(titanic_df)
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                       Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                            Brady, Mr. John Bertram    male  41.0      0
#
#     Parch       Ticket      Fare            Cabin Embarked
# 12      0        21228   82.2667              B45        S
# 14      0  W.E.P. 5734   61.1750              E31        S
# 24      3     PC 17608  262.3750  B57 B59 B63 B66        C
# 26      1       113509   61.9792              B36        C
# ...

# %%
# Excluir as colunas
titanic_df = titanic_df.drop(['SibSp', 'Parch'], axis=1)

# mostrar as primeiras linhas para confirmar a exclusão
print(titanic_df.head())
print(titanic_df.isna().sum())
print(titanic_df)
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name     Sex   Age  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0
# 26                       Ostby, Miss. Helene Ragnhild  female  22.0
# 28                            Brady, Mr. John Bertram    male  41.0
#
#          Ticket      Fare            Cabin Embarked
# 12        21228   82.2667              B45        S
# 14  W.E.P. 5734   61.1750              E31        S
# 24     PC 17608  262.3750  B57 B59 B63 B66        C
# 26       113509   61.9792              B36        C
# 28       113054   30.5000              A21        S
# PassengerId    0
# ...

# %%
print(titanic_df.to_string(index=False))
# Out:
#  PassengerId  Survived  Pclass                                                            Name    Sex  Age        Ticket     Fare           Cabin Embarked
#          904         1       1                   Snyder, Mrs. John Pillsbury (Nelle Stevenson) female 23.0         21228  82.2667             B45        S
#          906         1       1         Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood) female 47.0   W.E.P. 5734  61.1750             E31        S
#          916         1       1                 Ryerson, Mrs. Arthur Larned (Emily Maria Borie) female 48.0      PC 17608 262.3750 B57 B59 B63 B66        C
#          918         1       1                                    Ostby, Miss. Helene Ragnhild female 22.0        113509  61.9792             B36        C
#          920         0       1                                         Brady, Mr. John Bertram   male 41.0        113054  30.5000             A21        S
# ...

# %%
df.dropna(subset=['Age'],inplace=True)

# %%
#A
int(df[df['Survived'] == 1]['Age'].mean())
# Out:
# 30

# %%
#B
contagem_sexo = df['Sex'].value_counts()
print(contagem_sexo)
# Out:
# Sex
# male      205
# female    127
# Name: count, dtype: int64

# %%
#C
df[(df['Survived']) == 0]['Pclass'].value_counts()
# Out:
# Pclass
# 3    96
# 2    59
# 1    50
# Name: count, dtype: int64

# %%
df.dropna(subset=['Age'],inplace=True)

# %%
#D
df[(df['Sex'] == 'male') & (df['Age'] > 50) & (df['Embarked'] == 'C')]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 20           912         0       1           Rothschild, Mr. Martin  male
# 131         1023         0       1        Gracie, Col. Archibald IV  male
# 142         1034         0       1       Ryerson, Mr. Arthur Larned  male
# 177         1069         0       1  Stengel, Mr. Charles Emil Henry  male
# 236         1128         0       1         Warren, Mr. Frank Manley  male
# 316         1208         0       1    Spencer, Mr. William Augustus  male
#
#       Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 20   55.0      1      0  PC 17603   59.4000              NaN        C
# 131  53.0      0      0    113780   28.5000              C51        C
# 142  61.0      1      3  PC 17608  262.3750  B57 B59 B63 B66        C
# 177  54.0      1      0     11778   55.4417             C116        C
# 236  64.0      1      0    110813   75.2500              D37        C
# ...

# %%
import matplotlib.pyplot as plt

# %%
df_filtrado = df[df['Age'] < 18]
df_filtrado = df_filtrado['Sex'].value_counts()
print(df_filtrado)
# Out:
# Sex
# male      24
# female    17
# Name: count, dtype: int64

# %%
categorias = ['Homens', 'Mulheres']
valores = [24, 17]
plt.bar(categorias, valores)
plt.title("Homens e Mulheres com menos de 18 anos")
plt.xlabel("Categorias")
plt.ylabel("Valores")
plt.show()
